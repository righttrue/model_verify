# %%
import os
import glob

import numpy as np
import pandas as pd

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\20230705_스시2_서울&시흥_1월관측_후처리자료'
file_name = "seoul_1_gangbyeon_vaisala_20230119_U.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))

# %%
plt.figure(figsize=(16,9))
sns.lineplot(data = df , x = 'longitude',y= 'surface_temperature')
# sns.lineplot(data = df , x = 'timestamp',y= 'surface_temperature')

plt.show()

# %%
plt.figure(figsize=(16,9))
# sns.lineplot(data = df , x = 'longitude',y= 'surface_temperature')
sns.lineplot(data = df , x = 'timestamp',y= 'surface_temperature')

plt.show()

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\MODEL\seoul\jr\202301\19'
file_name = "KMA_HUFS_ROAD-P_seoul_20230119150000.csv"
df_pred = pd.read_csv(os.path.join(file_dir,file_name))

# %%
df_pred
# Out:
#                date_time          update_time    loc         lon        lat  \
# 0       2023-01-19 15:00  2023-01-19 15:00:00  seoul  127.113670  37.556764
# 1       2023-01-19 15:00  2023-01-19 15:00:00  seoul  127.113651  37.556681
# 2       2023-01-19 15:00  2023-01-19 15:00:00  seoul  127.113633  37.556598
# 3       2023-01-19 15:00  2023-01-19 15:00:00  seoul  127.113615  37.556520
# 4       2023-01-19 15:00  2023-01-19 15:00:00  seoul  127.113598  37.556442
# ...                  ...                  ...    ...         ...        ...
# 792620  2023-01-20 15:00  2023-01-19 15:00:00  seoul  127.134957  37.565758
# 792621  2023-01-20 15:00  2023-01-19 15:00:00  seoul  127.135041  37.565797
# 792622  2023-01-20 15:00  2023-01-19 15:00:00  seoul  127.135125  37.565837
# 792623  2023-01-20 15:00  2023-01-19 15:00:00  seoul  127.135213  37.565878
# 792624  2023-01-20 15:00  2023-01-19 15:00:00  seoul  127.135300  37.565920
#
# ...

# %%
plt.figure(figsize=(16,9))
# sns.lineplot(data = df_pred , x = 'lon',y= 'road_temp')
sns.lineplot(data = df_pred , x = 'timestamp',y= 'road_temp')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 3
#       1 plt.figure(figsize=(16,9))
#       2 # sns.lineplot(data = df_pred , x = 'lon',y= 'road_temp')
# ----> 3 sns.lineplot(data = df_pred , x = 'timestamp',y= 'road_temp')
#       5 plt.show()
#
# File c:\Users\user\anaconda3\envs\data\Lib\site-packages\seaborn\relational.py:485, in lineplot(data, x, y, hue, size, style, units, weights, palette, hue_order, hue_norm, sizes, size_order, size_norm, dashes, markers, style_order, estimator, errorbar, n_boot, seed, orient, sort, err_style, err_kws, legend, ci, ax, **kwargs)
#     471 def lineplot(
#     472     data=None, *,
#     473     x=None, y=None, hue=None, size=None, style=None, units=None, weights=None,
#    (...)
#     481
#     482     # Handle deprecation of ci parameter
#     483     errorbar = _deprecate_ci(errorbar, ci)
# ...

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\veri\dongbu\19'
file_name =  "dongbu20230119U_jr.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))
plt.figure(figsize=(20,9))
sns.lineplot(data = df , x = 'lon',y= 'road_temp')
sns.lineplot(data = df , x = 'lon',y= 'surface_temperature')
plt.show()

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\veri\dongbu\19'
file_name =  "dongbu20230119U_mg.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))
plt.figure(figsize=(20,9))
sns.lineplot(data = df , x = 'lon',y= 'road_temp')
sns.lineplot(data = df , x = 'lon',y= 'surface_temperature')
plt.show()

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\veri\dongbu\19'
file_name =  "dongbu20230119U_mg.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))
plt.figure(figsize=(20,9))
sns.scatterplot(data = df , x = 'lon',y= 'lat')
plt.show()

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\veri\dongbu\19'
file_name =  "dongbu20230119U_org.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))
plt.figure(figsize=(20,9))
sns.lineplot(data = df , x = 'lon',y= 'road_temp')
sns.lineplot(data = df , x = 'lon',y= 'surface_temperature')
plt.show()

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\veri\dongbu\19'
file_name =  "dongbu20230119U_ss.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))
plt.figure(figsize=(20,9))
sns.lineplot(data = df , x = 'lon',y= 'road_temp')
sns.lineplot(data = df , x = 'lon',y= 'surface_temperature')
plt.show()

# %%
file_dir = r'C:\Users\user\Desktop\모델검증\DATA\veri\dongbu\19'
file_name =  "dongbu20230119U_yc.csv"
df = pd.read_csv(os.path.join(file_dir,file_name))
plt.figure(figsize=(20,9))
sns.lineplot(data = df , x = 'lon',y= 'road_temp')
sns.lineplot(data = df , x = 'lon',y= 'surface_temperature')
plt.show()

# %%
df = pd.read_csv("C:/Users/user/Desktop/모델검증/DATA/veri/dongbu/19/dongbu20230119U_jr.csv")

# %%
df.columns
# Out:
# Index(['lon', 'lat', 'longitude', 'latitude', 'timestamp', 'relative_humidity',
#        'surface_temperature', 'ice_layer_thickness', 'surface_state',
#        'dew_point_temperature', 'water_layer_thickness',
#        'frost_point_temperature', 'ambient_temperature', 'grip',
#        'snow_layer_thickness', 'year', 'month', 'day', 'hour', 'date_time',
#        'update_time', 'loc', 'seq', 'p_hour', 'road_name', 'direction',
#        'altitude', 'link_id', 'road_temp', 'road_hydro', 'road_ice'],
#       dtype='object')

# %%
plt.figure(figsize=(20,9))
sns.lineplot(data = df , x = 'timestamp',y= 'road_temp')
sns.lineplot(data = df , x = 'timestamp',y= 'surface_temperature')
plt.show()

# %%
import plotly.express as px
df.sort_values(by="timestamp")
fig = px.scatter(df, x="timestamp", y="road_temp")
fig.show()
fig = px.scatter(df, x="timestamp", y="surface_temperature")
fig.show()
